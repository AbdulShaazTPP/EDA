# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
import seaborn as sns

# %%
df = pd.read_csv(r"D:\Datasets\shopping_trends.csv")
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.shape
# Out:
# (3900, 19)

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
df.describe(include = 'object')
# Out:
#        Gender Item Purchased  Category Location  Size  Color  Season  \
# count    3900           3900      3900     3900  3900   3900    3900
# unique      2             25         4       50     4     25       4
# top      Male         Blouse  Clothing  Montana     M  Olive  Spring
# freq     2652            171      1737       96  1755    177     999
#
#        Subscription Status Payment Method  Shipping Type Discount Applied  \
# count                 3900           3900           3900             3900
# unique                   2              6              6                2
# top                     No    Credit Card  Free Shipping               No
# freq                  2847            696            675             2223
#
#        Promo Code Used Preferred Payment Method Frequency of Purchases
# count             3900                     3900                   3900
# unique               2                        6                      7
# ...

# %%
df.dtypes
# Out:
# Customer ID                   int64
# Age                           int64
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)         int64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %% [markdown]
# DATA VISUALIZATION

# %% [markdown]
# DEMOGRAPHICS

# %% [markdown]
# Age Distribution

# %%
fig = px.histogram(
    df, 
    x = 'Age',
    nbins = 20,
    title = 'Age Distribution', 
    labels = {'Age':'Age(Years)', 'count': 'Number of Customers'}
)

fig.update_layout(
    xaxis_title = "Age(Years)",
    yaxis_title = "Number of Customers"
)
fig.update_layout(
    bargap = 0.2
)
fig.show()
# Out:
# <div>                            <div id="4403717a-d702-4fbf-bf63-46f88365cc2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4403717a-d702-4fbf-bf63-46f88365cc2b")) {                    Plotly.newPlot(                        "4403717a-d702-4fbf-bf63-46f88365cc2b",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Age(Years)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":20,"offsetgroup":"","orientation":"v","showlegend":false,"x":[55,19,50,21,45,46,63,27,26,57,53,30,61,65,64,64,25,53,52,66,21,31,56,31,18,18,38,56,54,31,57,33,36,54,36,54,35,35,29,70,69,67,20,25,39,50,57,55,42,68,49,59,42,29,47,40,41,21,69,63
# ...

# %% [markdown]
# Gender Distributon

# %%
px.pie(
    df, 
    names = 'Gender', 
    title = 'Gender Distribution',
    hole = 0.4, 
    labels = {'Gender': 'Gender'}
)
# Out:
# <div>                            <div id="1d186d11-ef2e-4225-a073-684840823d76" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d186d11-ef2e-4225-a073-684840823d76")) {                    Plotly.newPlot(                        "1d186d11-ef2e-4225-a073-684840823d76",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"Gender=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Ma
# ...

# %% [markdown]
# Age Group Distribution

# %%
bins = [0, 18, 30, 45, 60, 100]  
labels = ['0-18', '19-30', '31-45', '46-60', '60+'] 

df['Age Group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)


print(df[['Age', 'Age Group']].head())
# Out:
#    Age Age Group
# 0   55     46-60
# 1   19     19-30
# 2   50     46-60
# 3   21     19-30
# 4   45     46-60

# %%
bins = [0, 18, 30, 45, 60, 100]
labels = ['0-18', '19-30', '31-45', '46-60', '60+']
df['Age Group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)
age_group_counts = df['Age Group'].value_counts().reset_index()
age_group_counts.columns = ['Age Group', 'Number of People']

fig = px.bar(
    age_group_counts,
    x='Age Group',               
    y='Number of People',      
    title='Age Group Distribution',
    labels={'Age Group': 'Age Group', 'Number of People': 'Number of People'},
    text='Number of People' 
)

fig.update_traces(texttemplate='%{text}', textposition='outside')

fig.update_layout(
    xaxis_title="Age Group",
    yaxis_title="Number of People",
    title_x=0.5, 
    template='plotly'
)
fig.show()
# Out:
# <div>                            <div id="71577ee4-1bbb-4feb-a8e2-6c19aa83ed6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("71577ee4-1bbb-4feb-a8e2-6c19aa83ed6c")) {                    Plotly.newPlot(                        "71577ee4-1bbb-4feb-a8e2-6c19aa83ed6c",                        [{"alignmentgroup":"True","hovertemplate":"Age Group=%{x}\u003cbr\u003eNumber of People=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[1142.0,1092.0,878.0,788.0,0.0],"textposition":"outside","x":["46-60","31-45","19-30","60+","0-18"],"xaxis":"x","y":[1142,1092,878,788,0],"yaxis":"y","type":"bar","texttemplate":"%{text}"}], 
# ...

# %% [markdown]
# Purchase Trend by Gender

# %%
fig = px.bar(df,
    x = 'Gender',
    y = 'Purchase Amount (USD)',
    title = 'Purchase Trend by Gender',
    labels = {'Gender':'Gender', 'Purchase Amount(USD)':'Total Purchase Amount(USD)'},
    text = 'Purchase Amount (USD)'
)

fig.update_traces(texttemplate='%{text:.2f}', textposition='outside')
fig.update_layout(
    xaxis_title="Gender",
    yaxis_title="Total Purchase Amount (USD)",
    title_x=0.5,
    template='plotly'
)
# Out:
# <div>                            <div id="69293bae-fa71-4656-9bf1-aeda8eaa223d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69293bae-fa71-4656-9bf1-aeda8eaa223d")) {                    Plotly.newPlot(                        "69293bae-fa71-4656-9bf1-aeda8eaa223d",                        [{"alignmentgroup":"True","hovertemplate":"Gender=%{x}\u003cbr\u003ePurchase Amount (USD)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[53.0,64.0,73.0,90.0,49.0,20.0,85.0,34.0,97.0,31.0,34.0,68.0,72.0,51.0,53.0,81.0,36.0,38.0,48.0,90.0,51.0,62.0,37.0,88.0,22.0,25.0,20.0,56.0,94.0,48.0,31.0,79.0,67.0,38.0,91.0,33.0,69.0,45.
# ...

# %% [markdown]
# Item and Category

# %%
fig = px.bar(df,
    x = 'Item Purchased',
    y = 'Category',
    title = 'Item X Category',
    labels = {'Gender':'Gender', 'Purchase Amount(USD)':'Total Purchase Amount(USD)'},
)
fig.show()
# Out:
# <div>                            <div id="d943e5e6-fe60-4344-8bf1-e821a67992ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d943e5e6-fe60-4344-8bf1-e821a67992ae")) {                    Plotly.newPlot(                        "d943e5e6-fe60-4344-8bf1-e821a67992ae",                        [{"alignmentgroup":"True","hovertemplate":"Item Purchased=%{x}\u003cbr\u003eCategory=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Blouse","Sweater","Jeans","Sandals","Blouse","Sneakers","Shirt","Shorts","Coat","Handbag","Shoes","Shorts","Coat","Dress","Coat","Skirt","Sunglasses","Dress","Sweater","Pants",
# ...

# %% [markdown]
# Top 10 Popular Items

# %%
popular_items = df['Category'].value_counts().reset_index()
popular_items.columns = ['Category', 'Number of Purchases']
fig = px.bar(
    popular_items.head(10),
    x='Category',
    y='Number of Purchases',
    title='Top 10 Popular Items by Number of Purchases',
    labels={'Category': 'Category', 'Number of Purchases': 'Number of Purchases'},
    text='Number of Purchases' 
)
fig.update_traces(texttemplate='%{text}', textposition='outside')
fig.update_layout(
    xaxis_title="Category",
    yaxis_title="Number of Purchases",
    title_x=0.5,
    template='plotly',
    xaxis=dict(categoryorder='total descending')
)
fig.show()
# Out:
# <div>                            <div id="64ee5086-eaf5-497d-ae93-ab7d74f21400" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64ee5086-eaf5-497d-ae93-ab7d74f21400")) {                    Plotly.newPlot(                        "64ee5086-eaf5-497d-ae93-ab7d74f21400",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}\u003cbr\u003eNumber of Purchases=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[1737.0,1240.0,599.0,324.0],"textposition":"outside","x":["Clothing","Accessories","Footwear","Outerwear"],"xaxis":"x","y":[1737,1240,599,324],"yaxis":"y","type":"bar","texttemplate":"%{tex
# ...

# %% [markdown]
# Purchase Amount by Category

# %%
fig_box = px.box(
    df,
    x='Category',                 
    y='Purchase Amount (USD)',    
    title='Purchase Amount per Category: Box Plot',
    labels={'Category': 'Category', 'Purchase Amount (USD)': 'Purchase Amount (USD)'},
    color='Category'               
)
fig_box.update_layout(
    xaxis_title="Category",
    yaxis_title="Purchase Amount (USD)",
    title_x=0.5, 
    template='plotly'
)
fig_box.show()
# Out:
# <div>                            <div id="e6e1251c-d679-4fa8-bb73-e8cb79ed3409" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6e1251c-d679-4fa8-bb73-e8cb79ed3409")) {                    Plotly.newPlot(                        "e6e1251c-d679-4fa8-bb73-e8cb79ed3409",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}\u003cbr\u003ePurchase Amount (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Clothing","marker":{"color":"#636efa"},"name":"Clothing","notched":false,"offsetgroup":"Clothing","orientation":"v","showlegend":true,"x":["Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing",
# ...

# %% [markdown]
# Discounts Utilization

# %%
discount_data = df['Discount Applied'].value_counts().reset_index()
discount_data.columns = ['Discount Status', 'Count']
fig = px.pie(
    discount_data,
    names='Discount Status',  
    values='Count',         
    title='Discounts Utilization: Pie Chart',
    hole=0.4,              
    color='Discount Status',
    labels={'Discount Status': 'Discount Applied', 'Count': 'Number of Transactions'}
)
fig.update_traces(textinfo='percent+label')
fig.update_layout(
    title_x=0.5, 
    template='plotly'
)
fig.show()
# Out:
# <div>                            <div id="0b2b9a2b-c8d9-4d3c-9037-8f45cc866b5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b2b9a2b-c8d9-4d3c-9037-8f45cc866b5d")) {                    Plotly.newPlot(                        "0b2b9a2b-c8d9-4d3c-9037-8f45cc866b5d",                        [{"customdata":[["No"],["Yes"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"Discount Applied=%{customdata[0]}\u003cbr\u003eNumber of Transactions=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["No","Yes"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B"]},"name":"","showlegend":true,"values":[2223,1677],"type":"pie","textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"h
# ...

# %% [markdown]
# Popular Payment Method

# %%
payment_method_data = df['Payment Method'].value_counts().reset_index()
payment_method_data.columns = ['Payment Method', 'Number of Transactions']

fig = px.bar(
    payment_method_data,
    x='Payment Method',
    y='Number of Transactions',
    title='Popular Payment Methods',
    labels={'Payment Method': 'Payment Method', 'Number of Transactions': 'Number of Transactions'},
    text='Number of Transactions' 
)
fig.update_traces(texttemplate='%{text}', textposition='outside')
fig.update_layout(
    xaxis_title="Payment Method",
    yaxis_title="Number of Transactions",
    title_x=0.5, 
    template='plotly',
    xaxis=dict(categoryorder='total descending')
)
fig.show()
# Out:
# <div>                            <div id="19994f37-de18-40f6-adff-f89f7d5a117c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19994f37-de18-40f6-adff-f89f7d5a117c")) {                    Plotly.newPlot(                        "19994f37-de18-40f6-adff-f89f7d5a117c",                        [{"alignmentgroup":"True","hovertemplate":"Payment Method=%{x}\u003cbr\u003eNumber of Transactions=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[696.0,653.0,648.0,638.0,633.0,632.0],"textposition":"outside","x":["Credit Card","Venmo","Cash","PayPal","Debit Card","Bank Transfer"],"xaxis":"x","y":[696,653,648,638,633,632],"y
# ...

# %% [markdown]
# Shipping

# %%
shipping_data = df['Shipping Type'].value_counts().reset_index()
shipping_data.columns = ['Shipping Type', 'Count']

fig = px.pie(
    shipping_data,
    names='Shipping Type', 
    values='Count',    
    title='Shipping Type Distribution',
    hole=0.4,          
    color='Shipping Type',  
    labels={'Shipping Type': 'Shipping Type', 'Count': 'Number of Shipments'}
)
fig.update_traces(textinfo='percent+label') 
fig.update_layout(
    title_x=0.5, 
    template='plotly'
)
fig.show()
# Out:
# <div>                            <div id="be82a394-7fc2-4aa0-bebf-12d52a31a793" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be82a394-7fc2-4aa0-bebf-12d52a31a793")) {                    Plotly.newPlot(                        "be82a394-7fc2-4aa0-bebf-12d52a31a793",                        [{"customdata":[["Free Shipping"],["Standard"],["Store Pickup"],["Next Day Air"],["Express"],["2-Day Shipping"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"Shipping Type=%{customdata[0]}\u003cbr\u003eNumber of Shipments=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Free Shipping","Standard","Store Pickup","Next Day Air","Express","2-Day Shipping"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa","#
# ...

# %% [markdown]
# Relation between Rating and Purchase Amount

# %%
fig = px.scatter(
    df,
    x='Review Rating',              
    y='Purchase Amount (USD)',       
    title='Relationship Between Review Ratings and Purchase Amount',
    color='Review Rating',
    size='Purchase Amount (USD)',  
    hover_data=['Review Rating', 'Purchase Amount (USD)']
)
fig.update_layout(
    xaxis_title="Review Ratings",
    yaxis_title="Purchase Amount (USD)",
    title_x=0.5, 
    template='plotly'
)
fig.show()

# %% [markdown]
# Discounts and Reviews

# %%
fig = px.violin(
    df,
    x='Discount Applied',    
    y='Review Rating',        
    title='Effect of Discounts on Review Ratings',
    color='Discount Applied',    
    box=True,                   
    labels={'Discount Applied': 'Discount Applied', 'Review Rating': 'Review Rating'},
    hover_data=['Discount Applied', 'Review Rating']  
)


fig.update_layout(
    xaxis_title="Discount Applied",
    yaxis_title="Review Rating",
    title_x=0.5, 
    template='plotly'
)
fig.show()
