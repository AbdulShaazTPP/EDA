# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
import sklearn

# %%
df = pd.read_csv(r"D:\Datasets\coaster_db.csv")
df
# Out:
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# ...

# %%
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model  ...  speed1  \
# ...

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
ndf = df[['coaster_name', 
   #'Length', 'Speed', 'Location', 'Status', 'Opening date',
    #    'Type', 
    'Manufacturer', 
    #'Height restriction', 'Model', 
    'Height',
       #'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
       #'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
       #'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
       #'Track layout', 'Fastrack available', 'Soft opening date.1',
       #'Closing date',  'Replaced by', 'Website',
       'Opened',
       #'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
       #'Single rider line available', 'Restraint Style',
       #'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 'latitude', 'longitude', 'Type_Main',
       'opening_date_clean', 
       #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
       #'height_value', 'height_unit', 'height_ft',
       'Inversions_clean', 'Gforce_clean']]

# %%
ndf.head()
# Out:
#                              coaster_name            Manufacturer  \
# 0                      Switchback Railway  LaMarcus Adna Thompson
# 1                       Flip Flap Railway            Lina Beecher
# 2  Switchback Railway (Euclid Beach Park)                     NaN
# 3            Loop the Loop (Coney Island)          Edwin Prescott
# 4            Loop the Loop (Young's Pier)          Edwin Prescott
#
#          Height Opened  year_introduced  latitude  longitude Type_Main  \
# 0  50 ft (15 m)    NaN             1884   40.5740   -73.9780      Wood
# 1           NaN    NaN             1895   40.5780   -73.9790      Wood
# 2           NaN   1895             1896   41.5800   -81.5700     Other
# 3           NaN    NaN             1901   40.5745   -73.9780     Steel
# 4           NaN    NaN             1901   39.3538   -74.4342     Steel
#
#   opening_date_clean  speed_mph  Inversions_clean  Gforce_clean
# 0         1884-06-16        6.0                 0           2.9
# ...

# %%
ndf.columns
# Out:
# Index(['coaster_name', 'Manufacturer', 'Height', 'Opened', 'year_introduced',
#        'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph',
#        'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
ndf.dtypes
# Out:
# coaster_name           object
# Manufacturer           object
# Height                 object
# Opened                 object
# year_introduced         int64
# latitude              float64
# longitude             float64
# Type_Main              object
# opening_date_clean     object
# speed_mph             float64
# Inversions_clean        int64
# Gforce_clean          float64
# dtype: object

# %%
ndf['opening_date_clean'] = pd.to_datetime(ndf['opening_date_clean'])
# Out:
# C:\Users\abdul\AppData\Local\Temp\ipykernel_10080\3258769052.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ndf['opening_date_clean'] = pd.to_datetime(ndf['opening_date_clean'])

# %%
ndf = ndf.dropna(subset=['Height'])

# %%
ndf['Height'] = pd.to_numeric(ndf['Height'].str.replace(r'[^\d.]', '', regex=True), errors='coerce')

# %%
ndf.dtypes
# Out:
# coaster_name                  object
# Manufacturer                  object
# Height                       float64
# Opened                        object
# year_introduced                int64
# latitude                     float64
# longitude                    float64
# Type_Main                     object
# opening_date_clean    datetime64[ns]
# speed_mph                    float64
# Inversions_clean               int64
# Gforce_clean                 float64
# dtype: object

# %%
ndf.columns
# Out:
# Index(['coaster_name', 'Manufacturer', 'Height', 'Opened', 'year_introduced',
#        'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph',
#        'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
ndf = ndf.rename(columns = {'coaster_name' : 'Coaster_Name',
                    'year_introduced' : 'Year_Introduced',
                     'longitude' : 'Longitude',
                      'latitude' : 'Latitude', 
                       'opening_date_clean' : 'Opening_Date',
                        'speed_mph' : 'Speed', 
                         'Inversions_clean' : 'Inversions',
                         'Gforce_clean' : 'Gforce',
                             })

# %%
ndf.head()
# Out:
#                    Coaster_Name                  Manufacturer  Height Opened  \
# 0            Switchback Railway        LaMarcus Adna Thompson  5015.0    NaN
# 5                Cannon Coaster          George Francis Meyer  4012.0    NaN
# 6                 Leap-The-Dips  Federal Construction Company  4112.0    NaN
# 8                  Drop the Dip                 Arthur Jarvis  6018.0    NaN
# 13  Racer (1910 roller coaster)                  Charlie Mach     NaN    NaN
#
#     Year_Introduced  Latitude  Longitude Type_Main Opening_Date  Speed  \
# 0              1884   40.5740   -73.9780      Wood   1884-06-16    6.0
# 5              1902   40.5750   -73.9800      Wood   1902-01-01    NaN
# 6              1902       NaN        NaN      Wood   1902-01-01   10.0
# 8              1907   40.5744   -73.9786     Other   1907-06-06    NaN
# 13             1910   40.3869   -79.8619      Wood   1927-01-01   40.0
#
#     Inversions  Gforce
# 0            0     2.9
# 5            0     NaN
# ...

# %%
ndf.isna().sum()
# Out:
# Coaster_Name         0
# Manufacturer        24
# Height             203
# Opened             965
# Year_Introduced      0
# Latitude           239
# Longitude          239
# Type_Main            0
# Opening_Date       196
# Speed               61
# Inversions           0
# Gforce             613
# dtype: int64

# %%
ndf.loc[ndf.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Coaster_Name, Manufacturer, Height, Opened, Year_Introduced, Latitude, Longitude, Type_Main, Opening_Date, Speed, Inversions, Gforce]
# Index: []

# %%
ndf.loc[ndf.duplicated(subset = ['Coaster_Name'])]
# Out:
#                            Coaster_Name  \
# 43                Crystal Beach Cyclone
# 61          Blue Streak (Conneaut Lake)
# 167       Big Thunder Mountain Railroad
# 237   Thunder Run (Canada's Wonderland)
# 239                           La Vibora
# ...                                 ...
# 1059           Flight of the Hippogriff
# 1063                 Lil' Devil Coaster
# 1080                         Iron Gwazi
# 1082            American Dreier Looping
# 1084          Tron Lightcycle Power Run
#
#                                            Manufacturer   Height Opened  \
# 43                                   Traver Engineering   9629.0    NaN
# 61                                                  NaN   7723.0    NaN
# 167   Arrow Development (California and Florida)Dyna...  10432.0    NaN
# 237                                          Mack Rides   1033.0    NaN
# 239                                             Intamin   6018.0    NaN
# ...

# %%
ndf.query('Coaster_Name == "Crystal Beach Cyclone"')
# Out:
#              Coaster_Name        Manufacturer  Height Opened  Year_Introduced  \
# 39  Crystal Beach Cyclone  Traver Engineering  9629.0    NaN             1926
# 43  Crystal Beach Cyclone  Traver Engineering  9629.0    NaN             1927
#
#     Latitude  Longitude Type_Main Opening_Date  Speed  Inversions  Gforce
# 39   42.8617   -79.0598      Wood   1926-01-01   60.0           0     4.0
# 43   42.8617   -79.0598      Wood   1926-01-01   60.0           0     4.0

# %%
ndf1 = ndf.loc[~ndf.duplicated(subset = ['Coaster_Name', 'Opening_Date'])] \
.reset_index(drop = True)

# %%
ndf1.head()
# Out:
#                   Coaster_Name                  Manufacturer  Height Opened  \
# 0           Switchback Railway        LaMarcus Adna Thompson  5015.0    NaN
# 1               Cannon Coaster          George Francis Meyer  4012.0    NaN
# 2                Leap-The-Dips  Federal Construction Company  4112.0    NaN
# 3                 Drop the Dip                 Arthur Jarvis  6018.0    NaN
# 4  Racer (1910 roller coaster)                  Charlie Mach     NaN    NaN
#
#    Year_Introduced  Latitude  Longitude Type_Main Opening_Date  Speed  \
# 0             1884   40.5740   -73.9780      Wood   1884-06-16    6.0
# 1             1902   40.5750   -73.9800      Wood   1902-01-01    NaN
# 2             1902       NaN        NaN      Wood   1902-01-01   10.0
# 3             1907   40.5744   -73.9786     Other   1907-06-06    NaN
# 4             1910   40.3869   -79.8619      Wood   1927-01-01   40.0
#
#    Inversions  Gforce
# 0           0     2.9
# 1           0     NaN
# ...

# %%
ax = ndf1['Year_Introduced'].value_counts() \
.head(10) \
.plot(kind = 'bar', title = 'Top Coaster Introducing Years' )
ax.set_xlabel('Year Introduced')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ndf1['Speed'].plot(kind = 'hist', bins = 20, title = 'Roller Coaster Speed(mph)') \
.set_xlabel('Speed (mph)')
# Out:
# Text(0.5, 0, 'Speed (mph)')

# %%
ndf1['Speed'].plot(kind = 'kde', title = 'Roller Coaster Speed(mph)') \
.set_xlabel('Speed (mph)')
# Out:
# Text(0.5, 0, 'Speed (mph)')

# %%
sns.scatterplot(x = 'Speed',
               y = 'Height',
                data = ndf1 )
# Out:
# <Axes: xlabel='Speed', ylabel='Height'>

# %%
ndf1.head()
# Out:
#                   Coaster_Name                  Manufacturer  Height Opened  \
# 0           Switchback Railway        LaMarcus Adna Thompson  5015.0    NaN
# 1               Cannon Coaster          George Francis Meyer  4012.0    NaN
# 2                Leap-The-Dips  Federal Construction Company  4112.0    NaN
# 3                 Drop the Dip                 Arthur Jarvis  6018.0    NaN
# 4  Racer (1910 roller coaster)                  Charlie Mach     NaN    NaN
#
#    Year_Introduced  Latitude  Longitude Type_Main Opening_Date  Speed  \
# 0             1884   40.5740   -73.9780      Wood   1884-06-16    6.0
# 1             1902   40.5750   -73.9800      Wood   1902-01-01    NaN
# 2             1902       NaN        NaN      Wood   1902-01-01   10.0
# 3             1907   40.5744   -73.9786     Other   1907-06-06    NaN
# 4             1910   40.3869   -79.8619      Wood   1927-01-01   40.0
#
#    Inversions  Gforce
# 0           0     2.9
# 1           0     NaN
# ...

# %%
sns.pairplot(ndf1, vars = ['Year_Introduced', 'Speed', 'Height', 'Inversions', 'Gforce'])
plt.show()
